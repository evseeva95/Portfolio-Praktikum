# %% [markdown]
# # Задание

# %% [markdown]
# 1. Постройте диаграмму, отражающую количество клиентов в зависимости от числа используемых продуктов.
# 2. Добавьте на тот же график индикатор процента ушедших клиентов (уровень оттока среди владельцев данного числа продуктов).
# 3. Добавьте отдельно индикатор среднего оттока клиентов по банку, фильтр по городам, и фильтр по еще одному из важных признаков для оттока на усмотрение аналитика

# %% [markdown]
# https://public.tableau.com/app/profile/anastasiya.evseeva/viz/_16962780393600/Dashboard1?publish=yes

# %% [markdown]
# ![image.png](attachment:image.png)
